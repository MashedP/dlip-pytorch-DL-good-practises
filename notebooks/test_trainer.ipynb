# %%
import src
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/cyriaque/Documents/01_Projects/DliP/dlip-tp1-introduction-to-pytorch-and-practises/notebooks/test_trainer.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/home/cyriaque/Documents/01_Projects/DliP/dlip-tp1-introduction-to-pytorch-and-practises/notebooks/test_trainer.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import src
#
# ModuleNotFoundError: No module named 'src'
